# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathanael1235/WikiFetch/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# what is the first number 55
# what is the second number 75
# the two numbers added together is 130
